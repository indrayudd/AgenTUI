# %% [markdown]
# ## Introduction

# %%
print('Notebook demo: introduction')
# Out:
# Notebook demo: introduction

# %% [markdown]
# ## Generate Data

# %%
import math
values = [math.sin(i/10) for i in range(100)]
